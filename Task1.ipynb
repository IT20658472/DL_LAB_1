# %% [markdown]
# <a href="https://colab.research.google.com/github/IT20658472/DL_LAB_1/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arrysize= (4,4)
smpl1=np.random.exponential(1,arrysize)

# %%
arrysize = (1000,1)
smpl2=np.random.exponential(1,arrysize)
print(smpl2)
# Out:
# [[1.57090065e+00]
#  [9.13339760e-02]
#  [8.53517419e-01]
#  [2.19073253e-01]
#  [1.17140660e+00]
#  [2.95723684e+00]
#  [5.91980119e-01]
#  [1.51956609e+00]
#  [7.30949815e-01]
#  [1.30248571e-01]
#  [2.13418824e+00]
#  [1.57141354e+00]
#  [5.34549983e-01]
#  [8.81383784e-02]
#  [3.90550286e-01]
#  [1.12334150e+00]
#  [6.54904533e-01]
#  [8.58046952e-02]
#  [4.74275761e-01]
#  [2.81827101e-01]
#  [3.04715083e+00]
#  [9.75635679e-01]
#  [1.48858071e+00]
#  [4.30949602e-01]
#  [9.21864876e-01]
#  [2.45212353e+00]
#  [1.42537704e-01]
#  [4.65581050e+00]
#  [2.71105238e+00]
#  [2.43542881e+00]
#  [2.59760973e+00]
#  [1.61084427e-01]
#  [5.18164204e-01]
#  [2.40094106e+00]
#  [1.23917885e+00]
#  [9.32666026e-01]
#  [7.99523575e-01]
#  [1.76295702e+00]
#  [3.27985230e+00]
#  [2.72916808e-02]
#  [2.74863408e-01]
#  [6.38657583e-02]
#  [5.34568034e-01]
#  [1.42257076e+00]
#  [1.21527627e+00]
#  [1.41898837e+00]
#  [1.54623902e+00]
#  [1.68528758e-01]
#  [4.90656858e-02]
#  [1.32413827e+00]
# ...

# %%
import matplotlib.pyplot as plt

# %%
 plt.hist(np.random.rand(100000), density=True, bins=200, histtype="step", color="blue", label="rand")
 plt.axis([-2.5, 2.5, 0, 1.1])
 plt.legend(loc = "upper left")
 plt.title("Random distributions")
 plt.xlabel("Value")
 plt.ylabel("Density")
 plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sqrt(X*2 + Y*2)

fig = plt.figure(figsize=(12, 4))
subplot3d = fig.add_subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.coolwarm, linewidth=0.1)
plt.show()
# Out:
# <ipython-input-7-7cfa79b4d711>:6: RuntimeWarning: invalid value encountered in sqrt
#   Z = np.sqrt(X*2 + Y*2)
